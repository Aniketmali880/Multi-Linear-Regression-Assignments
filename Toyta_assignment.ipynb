# %% [markdown]
# # Asgginment2(toyta)

# %%
## importing laibaries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
## loading the dataset
toyta_1=pd.read_csv("ToyotaCorolla.csv", encoding='windows-1252')

# %%
toyta_1.shape
# Out:
# (1436, 38)

# %%
toyta_1.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
## droping of unnessary colums
toyta_1.drop(['Tow_Bar','Radio_cassette','Metallic_Rim','Backseat_Divider','Sport_Model','Mistlamps','Radio','Power_Steering'],
            axis=1,inplace=True)

# %%
toyta_1.shape
# Out:
# (1436, 30)

# %%
toyta_1.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Guarantee_Period  \
# 0         10      2002  46986    Diesel  90          1  ...                3
# 1         10      2002  72937    Diesel  90          1  ...                3
# 2          9      2002  41711    Diesel  90          1  ...                3
# 3          7      2002  48000    Diesel  90          0  ...                3
# 4          3      2002  38500    Diesel  90          0  ...                3
#
# ...

# %%
toyta_1.drop(['Powered_Windows','Central_Lock','Automatic_airco','Airco'
                                   ,'Airbag_2','Airbag_1','ABS',],axis=1,inplace=True)

# %%
toyta_1.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Doors  Cylinders  \
# 0         10      2002  46986    Diesel  90          1  ...     3          4
# 1         10      2002  72937    Diesel  90          1  ...     3          4
# 2          9      2002  41711    Diesel  90          1  ...     3          4
# 3          7      2002  48000    Diesel  90          0  ...     3          4
# 4          3      2002  38500    Diesel  90          0  ...     3          4
#
#    Gears  Quarterly_Tax  Weight  Mfr_Guarantee  BOVAG_Guarantee  \
# ...

# %%
toyta_1.drop(['Mfr_Guarantee','BOVAG_Guarantee','Guarantee_Period','Boardcomputer','CD_Player'],axis=1,inplace=True)

# %%
toyta_1.shape
# Out:
# (1436, 18)

# %%
toyta_1.tail()
# Out:
#         Id                                              Model  Price  \
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  Color  \
# 1431         69         12      1998  20544    Petrol   86          1   Blue
# 1432         72          9      1998  19000    Petrol   86          0   Grey
# 1433         71         10      1998  17016    Petrol   86          0   Blue
# 1434         70         11      1998  16916    Petrol   86          1   Grey
# 1435         76          5      1998      1    Petrol  110          0  Green
#
#       Automatic    cc  Doors  Cylinders  Gears  Quarterly_Tax  Weight
# ...

# %%
toyta_1.drop(['Id','Model','Mfg_Month','Mfg_Year','Fuel_Type','Met_Color','Color','Automatic','Gears'],
                      axis=1,inplace=True)

# %%
toyta_1.shape
# Out:
# (1436, 9)

# %% [markdown]
# ## Droping all the colums which are not required

# %%
toyta_1.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Cylinders  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3          4            210    1165
# 1  13750         23  72937  90  2000      3          4            210    1165
# 2  13950         24  41711  90  2000      3          4            210    1165
# 3  14950         26  48000  90  2000      3          4            210    1165
# 4  13750         30  38500  90  2000      3          4            210    1170

# %% [markdown]
# ## Graphical reprentation

# %%
toyta_1.isnull().sum()
# Out:
# Price            0
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Cylinders        0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
## chaking for Age_08_04
## histogram
sns.distplot(toyta_1['Age_08_04'])
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
# Out:
# C:\Users\Aniket Mali\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## box plot
sns.boxplot(toyta_1['Age_08_04'])
# Out:
# <AxesSubplot:xlabel='Age_08_04'>

# %%
## fetching outliers using whiskers
def outliers(toyta_1, feature):
    Q1= toyta_1[feature].quantile(0.25)
    Q3 = toyta_1[feature].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return upper_limit, lower_limit

upper, lower = outliers(toyta_1, "Age_08_04")
print("Upper whisker: ", upper)
print("Lower Whisker: ", lower)
# Out:
# Upper whisker:  109.0
# Lower Whisker:  5.0

# %%
## to find outliers
toyta_1[(toyta_1['Age_08_04'] < lower) | (toyta_1['Age_08_04'] > upper)].shape
# Out:
# (7, 9)

# %%
## Dropping outliers
toyta_2=toyta_1[(toyta_1['Age_08_04'] > lower) & (toyta_1['Age_08_04'] < upper)]

# %%
sns.boxplot(toyta_2['Age_08_04'])
# Out:
# <AxesSubplot:xlabel='Age_08_04'>

# %% [markdown]
# ## outliers are remove

# %%
## chaking for KM
## histogram
sns.distplot(toyta_2['KM'])
# Out:
# <AxesSubplot:xlabel='KM', ylabel='Density'>

# %%
## Boxplot
sns.boxplot(toyta_2['KM'])
# Out:
# <AxesSubplot:xlabel='KM'>

# %%
## fetching outliers
def outliers(toyta_2, feature):
    Q1= toyta_2[feature].quantile(0.25)
    Q3 = toyta_2[feature].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return upper_limit, lower_limit

upper, lower = outliers(toyta_2, "KM")
print("Upper whisker: ", upper)
print("Lower Whisker: ", lower)
# Out:
# Upper whisker:  153505.0
# Lower Whisker:  -23111.0

# %%
## to find outliers
toyta_2[(toyta_2['KM'] < lower) | (toyta_2['KM'] > upper)].shape
# Out:
# (49, 9)

# %%
## Dropping outliers
toyta_3=toyta_2[(toyta_2['KM'] > lower) & (toyta_2['KM'] < upper)]

# %%
sns.boxplot(toyta_3['KM'])
# Out:
# <AxesSubplot:xlabel='KM'>

# %%
sns.distplot(toyta_3['KM'])
# Out:
# <AxesSubplot:xlabel='KM', ylabel='Density'>

# %% [markdown]
# ## Data looks normally distributed

# %%
## chaking for HP
## histogram
sns.distplot(toyta_3['HP'])
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %% [markdown]
# ## Chaking the relation between target and HP by using scatterplot

# %%
x1=toyta_3['HP']
y1=toyta_3['Price']

# %%
plt.scatter(x1, y1, c ="yellow", linewidths = 1, marker =".", edgecolor ="black", s = 100)
plt.title("HP VS Price")
plt.xlabel("HP")
plt.ylabel("Price")
plt.show()

# %%
## chaking for tje outliers
sns.boxplot(toyta_3['HP'])
# Out:
# <AxesSubplot:xlabel='HP'>

# %%
## Fetching outliers using boxplot
def outliers(toyta_3, feature):
    Q1= toyta_3[feature].quantile(0.25)
    Q3 = toyta_3[feature].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return upper_limit, lower_limit

upper, lower = outliers(toyta_3, "HP")
print("Upper whisker: ", upper)
print("Lower Whisker: ", lower)
# Out:
# Upper whisker:  140.0
# Lower Whisker:  60.0

# %%
## to find outliers
toyta_3[(toyta_3['HP'] < lower) | (toyta_3['HP'] > upper)].shape
# Out:
# (11, 9)

# %%
## Dropping outliers
toyta_4=toyta_3[(toyta_3['HP'] > lower) & (toyta_3['HP'] < upper)]

# %%
sns.boxplot(toyta_4['HP'])
# Out:
# <AxesSubplot:xlabel='HP'>

# %% [markdown]
# ## ALL outliers are removed

# %%
## chaking for cc
## histogram
sns.distplot(toyta_4['cc'])
# Out:
# <AxesSubplot:xlabel='cc', ylabel='Density'>

# %%
sns.boxplot(toyta_4['cc'])
# Out:
# <AxesSubplot:xlabel='cc'>

# %%
## Fetching outliers using boxplot
def outliers(toyta_4, feature):
    Q1= toyta_3[feature].quantile(0.25)
    Q3 = toyta_3[feature].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return upper_limit, lower_limit

upper, lower = outliers(toyta_4, "cc")
print("Upper whisker: ", upper)
print("Lower Whisker: ", lower)
# Out:
# Upper whisker:  1900.0
# Lower Whisker:  1100.0

# %%
## to find outliers
toyta_4[(toyta_4['cc'] < lower) | (toyta_4['cc'] > upper)].shape
# Out:
# (92, 9)

# %%
## chaking relationship between target & CC
P=toyta_4['Price']
C=toyta_4['cc']

# %%
plt.scatter(C, P,)
plt.show()

# %%
## Chaking for doors
## histogram
sns.distplot(toyta_4['Doors'])
# Out:
# <AxesSubplot:xlabel='Doors', ylabel='Density'>

# %%
sns.boxplot(toyta_4['Doors'])
# Out:
# <AxesSubplot:xlabel='Doors'>

# %%
## chaking for Cylinders
## histogram
sns.distplot(toyta_4['Cylinders'])
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='Density'>

# %%
sns.boxplot(toyta_4['Cylinders'])
# Out:
# <AxesSubplot:xlabel='Cylinders'>

# %%
## Chaking for Quarterly_Tax
## Histogram
sns.distplot(toyta_4['Quarterly_Tax'])
# Out:
# <AxesSubplot:xlabel='Quarterly_Tax', ylabel='Density'>

# %%
sns.boxplot(toyta_4['Quarterly_Tax'])
# Out:
# <AxesSubplot:xlabel='Quarterly_Tax'>

# %%
## Fetching outliers using boxplot
def outliers(toyta_4, feature):
    Q1= toyta_4[feature].quantile(0.25)
    Q3 = toyta_4[feature].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return upper_limit, lower_limit

upper, lower = outliers(toyta_4, "Quarterly_Tax")
print("Upper whisker: ", upper)
print("Lower Whisker: ", lower)
# Out:
# Upper whisker:  109.0
# Lower Whisker:  45.0

# %%
## to find outliers
toyta_4[(toyta_4['Quarterly_Tax'] < lower) | (toyta_4['Quarterly_Tax'] > upper)].shape
# Out:
# (183, 9)

# %%
## Dropping outliers
toyta_5=toyta_4[(toyta_4['Quarterly_Tax'] > lower) & (toyta_4['Quarterly_Tax'] < upper)]

# %%
sns.boxplot(toyta_5['Quarterly_Tax'])
# Out:
# <AxesSubplot:xlabel='Quarterly_Tax'>

# %%
sns.distplot(toyta_5['Quarterly_Tax'])
# Out:
# <AxesSubplot:xlabel='Quarterly_Tax', ylabel='Density'>

# %%
## chaking for Weight
sns.distplot(toyta_5['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.boxplot(toyta_5['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
## Fetching outliers using boxplot
def outliers(toyta_5, feature):
    Q1= toyta_5[feature].quantile(0.25)
    Q3 = toyta_5[feature].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return upper_limit, lower_limit

upper, lower = outliers(toyta_5, "Weight")
print("Upper whisker: ", upper)
print("Lower Whisker: ", lower)
# Out:
# Upper whisker:  1135.0
# Lower Whisker:  975.0

# %%
## to find outliers
toyta_5[(toyta_5['Weight'] < lower) | (toyta_5['Weight'] > upper)].shape
# Out:
# (14, 9)

# %%
## Dropping outliers
toyta_6=toyta_5[(toyta_5['Weight'] > lower) & (toyta_5['Weight'] < upper)]

# %%
sns.boxplot(toyta_6['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
sns.distplot(toyta_6['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(toyta_6)

# %% [markdown]
# ## correlation

# %%
toyta_6.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.892274 -0.608053  0.174859  0.127202  0.201072
# Age_08_04     -0.892274   1.000000  0.570667 -0.089394 -0.060683 -0.143880
# KM            -0.608053   0.570667  1.000000 -0.008038  0.066399 -0.041520
# HP             0.174859  -0.089394 -0.008038  1.000000  0.908910  0.170203
# cc             0.127202  -0.060683  0.066399  0.908910  1.000000  0.183043
# Doors          0.201072  -0.143880 -0.041520  0.170203  0.183043  1.000000
# Cylinders           NaN        NaN       NaN       NaN       NaN       NaN
# Quarterly_Tax  0.426731  -0.323575 -0.161632  0.455721  0.403390  0.569681
# Weight         0.633419  -0.510531 -0.233177  0.489207  0.533005  0.509215
#
#                Cylinders  Quarterly_Tax    Weight
# Price                NaN       0.426731  0.633419
# Age_08_04            NaN      -0.323575 -0.510531
# KM                   NaN      -0.161632 -0.233177
# ...

# %%
## Heatmap
corr = toyta_6.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
## cylinder colum doesn't have any value so we can drop it
toyta_7=toyta_6.drop(['Cylinders'],axis=1)

# %%
toyta_7.head(5)
# Out:
#     Price  Age_08_04     KM   HP    cc  Doors  Quarterly_Tax  Weight
# 17  17950         24  21716  110  1600      3             85    1105
# 19  16950         30  64359  110  1600      3             85    1105
# 20  15950         30  67660  110  1600      3             85    1105
# 22  15950         28  56349  110  1600      3             85    1120
# 23  16950         28  32220  110  1600      3             85    1120

# %% [markdown]
# # Building of model

# %%
## chaking for price
sns.distplot(toyta_7['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(toyta_7['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
## Fetching outliers using boxplot
def outliers(toyta_7, feature):
    Q1= toyta_7[feature].quantile(0.25)
    Q3 = toyta_7[feature].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return upper_limit, lower_limit

upper, lower = outliers(toyta_7, "Price")
print("Upper whisker: ", upper)
print("Lower Whisker: ", lower)
# Out:
# Upper whisker:  16425.0
# Lower Whisker:  3745.0

# %%
## to find outliers
toyta_7[(toyta_7['Price'] < lower) | (toyta_7['Price'] > upper)].shape
# Out:
# (75, 8)

# %%
## Dropping outliers
toyta_8=toyta_7[(toyta_7['Price'] > lower) & (toyta_7['Price'] < upper)]

# %%
sns.distplot(toyta_8['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(toyta_8['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
## Fetching outliers using boxplot
def outliers(toyta_8, feature):
    Q1= toyta_8[feature].quantile(0.25)
    Q3 = toyta_8[feature].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return upper_limit, lower_limit

upper, lower = outliers(toyta_8, "Price")
print("Upper whisker: ", upper)
print("Lower Whisker: ", lower)
# Out:
# Upper whisker:  14700.0
# Lower Whisker:  4700.0

# %%
## to find outliers
toyta_8[(toyta_8['Price'] < lower) | (toyta_8['Price'] > upper)].shape
# Out:
# (43, 8)

# %%
## Dropping outliers
toyta_9=toyta_8[(toyta_8['Price'] > lower) & (toyta_8['Price'] < upper)]

# %%
sns.distplot(toyta_9['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# ## our target looks like normally distributed

# %%
## dividing target & features
x=toyta_9.drop(['Price'],axis=1)
y=toyta_9['Price']

# %%
x.head()
# Out:
#      Age_08_04      KM   HP    cc  Doors  Quarterly_Tax  Weight
# 40          22   49059   97  1400      3             85    1100
# 42          22   46961   97  1400      3             85    1100
# 55          32   45725  110  1600      5             85    1075
# 71          32   29198   97  1400      5             85    1060
# 192         44  131273   69  1800      5             64    1110

# %%
y.head()
# Out:
# 40     13950
# 42     13950
# 55     13250
# 71     12995
# 192     4750
# Name: Price, dtype: int64

# %%
## Splitting the data into train & test
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # MODEL1

# %%
ml1= LinearRegression()

# %% [markdown]
# ## model fitting

# %%
## Fitting the model
ml1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the result

# %%
y_pred=ml1.predict(x_test)
print (y_pred)
# Out:
# [10236.97423503  8006.73226651  8046.60872054  8464.33539662
#  12410.40526289  9329.6752999   9119.92651917  8335.9387359
#  12611.39453581  9583.95118781 10081.89553813  9556.06088637
#  11944.48308856  7060.87328612  8575.34855553 10622.27119767
#   8280.7202811   7664.11075002 11660.80570199  8065.66772762
#  12217.14325979  9154.79306342 11626.3750997  10371.55435135
#   8082.38600077 14388.97718651 10085.56814905 12562.56772952
#   8293.81236534 10213.17053873 11028.54971047  8554.08346604
#   8683.18273225  9771.31307927  9277.16363984 10251.78554762
#   8989.00288389  8149.47421956 10886.60812053  9082.2414316
#  10052.7818553  10289.43119939 10814.68277051  9098.15162206
#   8931.46434486  9422.95175658  9889.9339434   9691.36220382
#   8985.70106283 10209.389       7817.16781891  9992.93335984
#  10063.40211335  9115.50746869 10126.65062261  9543.08689331
#  12919.1721717  12087.59047579  9657.0746514  11327.87945247
# ...

# %% [markdown]
# # Model evaluation

# %% [markdown]
# ## Chaking of R2 Score

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7088186370624832

# %%
## Q-Q plot
plt.figure(figsize=(15,10))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Pred')
plt.title("Actual VS Pred ")
# Out:
# Text(0.5, 1.0, 'Actual VS Pred ')

# %% [markdown]
# ## our 1st model is not giving linear Q-Q plot & also not have good R2 score it means model1 has strong multicolinearity between features to fetures which is already given by the heat map so we need to drop unuseful colums

# %%
corr = toyta_9.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## From above Weight factor showing strong multicolinearity between many features so we need to drop weight colum

# %%
toyta_10=toyta_9.drop('Weight',axis=1)

# %%
toyta_10.head()
# Out:
#      Price  Age_08_04      KM   HP    cc  Doors  Quarterly_Tax
# 40   13950         22   49059   97  1400      3             85
# 42   13950         22   46961   97  1400      3             85
# 55   13250         32   45725  110  1600      5             85
# 71   12995         32   29198   97  1400      5             85
# 192   4750         44  131273   69  1800      5             64

# %%
corr = toyta_10.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## from above cc& doors also shows strong multi colinearity between features so we need to drop it .

# %%
toyta_11=toyta_10.drop(['cc','Doors'],axis=1)

# %%
toyta_11.head()
# Out:
#      Price  Age_08_04      KM   HP  Quarterly_Tax
# 40   13950         22   49059   97             85
# 42   13950         22   46961   97             85
# 55   13250         32   45725  110             85
# 71   12995         32   29198   97             85
# 192   4750         44  131273   69             64

# %%
corr = toyta_11.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## from above we can drop HP beacuse it shows strong multicolinearity

# %%
toyta_12=toyta_11.drop('HP',axis=1)

# %%
toyta_12.head()
# Out:
#      Price  Age_08_04      KM  Quarterly_Tax
# 40   13950         22   49059             85
# 42   13950         22   46961             85
# 55   13250         32   45725             85
# 71   12995         32   29198             85
# 192   4750         44  131273             64

# %%
corr = toyta_12.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Building 2nd model

# %%
## dividing target & features
X=toyta_12.drop(['Price'],axis=1)
Y=toyta_12['Price']

# %%
X.head()
# Out:
#      Age_08_04      KM  Quarterly_Tax
# 40          22   49059             85
# 42          22   46961             85
# 55          32   45725             85
# 71          32   29198             85
# 192         44  131273             64

# %%
Y.head()
# Out:
# 40     13950
# 42     13950
# 55     13250
# 71     12995
# 192     4750
# Name: Price, dtype: int64

# %%
## Splitting the data into train & test
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %% [markdown]
# # Model2

# %%
## Fitting the model
ml2=ml1.fit(X_train,Y_train)

# %%
Y_pred=ml2.predict(X_test)
print (Y_pred)
# Out:
# [10250.16233083  7962.42207997  7860.58468333  8424.7726692
#  12387.33239133  9460.94854426  9025.24643395  8236.9716847
#  12546.58221889  9591.27449243 10219.73212666  9564.42286525
#  11980.97993241  7309.35133978  8916.65034376 10547.36648324
#   8240.27494034  7562.38208268 11573.39647008  7966.80147222
#  12194.24360588  8972.2959743  11680.21092598 10281.9559843
#   8083.27013371 14219.37402676  9967.57780384 12647.25378737
#   8296.01773476 10225.27134548 10999.91768245  8369.60157841
#   8680.55078247  9590.46068957  9093.36176114 10264.63260472
#   8995.0567436   8152.25378402 10903.60186363  8900.74101573
#  10186.1550044  10300.61267089 10786.20458257  9060.24985999
#   8934.9218184   9289.8041554   9902.08573532  9700.91632786
#   8950.17832271 10030.36846263  7819.98983899  9813.7092603
#  10196.43028235  9117.33246112 10345.37003625  9449.1597301
#  12643.58711607 12064.92395383  9523.8992214  11300.23885972
# ...

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# ## R2 score

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.7107859297439504

# %%
## Q-Q plot
plt.figure(figsize=(15,10))
plt.scatter(Y_test,Y_pred)
plt.xlabel('Actual')
plt.ylabel('Pred')
plt.title("Actual VS Pred ")
# Out:
# Text(0.5, 1.0, 'Actual VS Pred ')

# %%
import statsmodels.formula.api as smf

# %%
model1=smf.ols(formula="Y ~ X", data=toyta_12).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.716
# Method:                 Least Squares   F-statistic:                     878.3
# Date:                Mon, 18 Apr 2022   Prob (F-statistic):          1.43e-284
# Time:                        19:09:07   Log-Likelihood:                -8651.5
# No. Observations:                1045   AIC:                         1.731e+04
# Df Residuals:                    1041   BIC:                         1.733e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.276e+04    341.457     37.357      0.000    1.21e+04    1.34e+04
# ...

# %% [markdown]
# ## From above all Features are important as our p value is less than 0.05

# %%
##Q_Q plot
import statsmodels.api as sm
qqplot=sm.qqplot(model1.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %% [markdown]
# ## prediction for new values

# %%
new_data=pd.DataFrame({'Age_08_04':20,"KM":48000,"Quarterly_Tax":80,},index=[1])

# %%
ml2.predict(new_data)
# Out:
# array([14143.65628474])

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ## model1 shows wrost performeance as there is strong multicolinearity between features to fetures whrere as model2 gives better prediction as R2 is better & also giving linear Q-Q plot
